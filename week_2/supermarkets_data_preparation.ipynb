# %% [markdown]
# # Importing and preparing supermarkets data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import fnmatch
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing data

# %%
# Get current working directory
print('Current working directory:', os.getcwd())

# Show files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.json')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df1 = pd.read_json('supermarkets_data.json', encoding='utf-8')
df1.head(5)
# Out:
# Current working directory: /Users/miroduman/Desktop/data analytics/Woche_2
# supermarkets_data.json
#    type        id        lat       lon  \
# 0  node  33126515  47.155616  9.037915
# 1  node  36726161  47.226191  8.980329
# 2  node  39768209  47.225069  8.969981
# 3  node  39947904  47.376732  8.542161
# 4  node  48932835  47.375020  8.522895
#
#                                                 tags
# 0  {'brand': 'Spar', 'brand:wikidata': 'Q610492',...
# 1  {'addr:city': 'Uznach', 'addr:housenumber': '2...
# 2  {'addr:city': 'Uznach', 'addr:postcode': '8730...
# 3  {'addr:city': 'Zürich', 'addr:country': 'CH', ...
# 4  {'addr:city': 'Zürich', 'addr:housenumber': '7...

# %% [markdown]
# ## Count number of rows and columns in the data frame

# %%
# Dimension (rows, columns)
print('Dimension:', df1.shape)

# Number of rows
print('Number of rows:', df1.shape[0])

# Number of columns
print('Number of columns:', df1.shape[1])
# Out:
# Dimension: (3260, 5)
# Number of rows: 3260
# Number of columns: 5

# %% [markdown]
# ## Column 'tags' is a pandas Series with dictionaries -> change to data frame

# %%
# Type of the first item of column tags
print(type(df1.tags))
print(type(df1.tags[0]))

# Content of the first item of column tags
print(df1.tags[0].keys())

# Change to data frame
df2 = pd.DataFrame.from_records(df1.tags)
df2[['brand', 'shop', 'addr:city', 'addr:housenumber', 'addr:postcode', 'opening_hours']]
# Out:
# <class 'pandas.core.series.Series'>
# <class 'dict'>
# dict_keys(['brand', 'brand:wikidata', 'brand:wikipedia', 'name', 'opening_hours', 'shop'])
#        brand         shop        addr:city addr:housenumber addr:postcode  \
# 0       Spar  supermarket              NaN              NaN           NaN
# 1     Migros  supermarket           Uznach               25          8730
# 2       Coop  supermarket           Uznach              NaN          8730
# 3       Coop  supermarket           Zürich                1          8001
# 4     Migros  supermarket           Zürich                7          8004
# ...      ...          ...              ...              ...           ...
# 3255    Volg  supermarket              NaN              NaN           NaN
# 3256   Landi  supermarket  Rickenbach Sulz                1          8545
# 3257     VOI  supermarket              NaN              NaN           NaN
# 3258     NaN  supermarket              NaN              NaN           NaN
# 3259     NaN  supermarket              NaN              NaN           NaN
#
#                                           opening_hours
# 0     Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00
# 1     Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                   NaN
# 3                                     Mo-Sa 06:00-22:00
# 4                             Mo-Sa 08:00-21:00; PH off
# ...                                                 ...
# 3255      Mo-Fr 07:00-12:20,13:30-18:30; Sa 07:00-16:00
# 3256          Mo-Fr 08:00-18.30; Sa 08:00-17:00; PH off
# 3257                                                NaN
# 3258       Mo-Fr 09:00-19:00; Sa,Su 09:00-17:00; PH off
# 3259                                                NaN
#
# [3260 rows x 6 columns]

# %% [markdown]
# ## Join df1 and df2

# %%
# Merge df and df2
df = pd.merge(df1[['type', 'id', 'lat', 'lon']], 
              df2[['brand', 'shop', 'addr:city', 'addr:housenumber', 'addr:postcode', 'opening_hours']], 
              left_index=True, 
              right_index=True)
df.head(5)
# Out:
#    type        id        lat       lon   brand         shop addr:city  \
# 0  node  33126515  47.155616  9.037915    Spar  supermarket       NaN
# 1  node  36726161  47.226191  8.980329  Migros  supermarket    Uznach
# 2  node  39768209  47.225069  8.969981    Coop  supermarket    Uznach
# 3  node  39947904  47.376732  8.542161    Coop  supermarket    Zürich
# 4  node  48932835  47.375020  8.522895  Migros  supermarket    Zürich
#
#   addr:housenumber addr:postcode  \
# 0              NaN           NaN
# 1               25          8730
# 2              NaN          8730
# 3                1          8001
# 4                7          8004
#
#                                        opening_hours
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...
# 2                                                NaN
# 3                                  Mo-Sa 06:00-22:00
# 4                          Mo-Sa 08:00-21:00; PH off

# %% [markdown]
# ## Count and identify the number of missing values (if any)

# %%
# Count missing values
print(pd.isna(df).sum())

# Identify rows with missing values, e.g.:
df.loc[pd.isna(df['addr:city'])]
# Out:
# type                   0
# id                     0
# lat                    0
# lon                    0
# brand               1246
# shop                   0
# addr:city           1808
# addr:housenumber    1702
# addr:postcode       1733
# opening_hours       1435
# dtype: int64
#       type          id        lat       lon  brand         shop addr:city  \
# 0     node    33126515  47.155616  9.037915   Spar  supermarket       NaN
# 5     node    60271452  47.406671  9.305450    NaN  supermarket       NaN
# 6     node    70656485  47.491253  8.733981    NaN  supermarket       NaN
# 10    node    81321513  47.532917  9.066408  Landi  supermarket       NaN
# 13    node    95582038  47.050385  9.059214    NaN  supermarket       NaN
# ...    ...         ...        ...       ...    ...          ...       ...
# 3253  node  9947587529  47.000852  8.611420    NaN  supermarket       NaN
# 3255  node  9963973121  47.321761  9.426943   Volg  supermarket       NaN
# 3257  node  9975876019  46.011774  8.965955    VOI  supermarket       NaN
# 3258  node  9978766657  47.424524  7.126737    NaN  supermarket       NaN
# 3259  node  9979931913  46.010662  8.856326    NaN  supermarket       NaN
#
#      addr:housenumber addr:postcode  \
# 0                 NaN           NaN
# 5                 NaN           NaN
# 6                 NaN           NaN
# 10                NaN           NaN
# 13                NaN           NaN
# ...               ...           ...
# 3253              NaN           NaN
# 3255              NaN           NaN
# 3257              NaN           NaN
# 3258              NaN           NaN
# 3259              NaN           NaN
#
#                                           opening_hours
# 0     Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00
# 5                                                   NaN
# 6                                                   NaN
# 10                       Mo-Sa 08:00-12:00, 13:30-18:00
# 13                                                  NaN
# ...                                                 ...
# 3253                                                NaN
# 3255      Mo-Fr 07:00-12:20,13:30-18:30; Sa 07:00-16:00
# 3257                                                NaN
# 3258       Mo-Fr 09:00-19:00; Sa,Su 09:00-17:00; PH off
# 3259                                                NaN
#
# [1808 rows x 10 columns]

# %% [markdown]
# ## Count and identify duplicated values (if any)

# %%
# Count duplicated values
print(df.duplicated().sum())

# Identify rows with duplicated values, e.g.:
df[df[['id']].duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [type, id, lat, lon, brand, shop, addr:city, addr:housenumber, addr:postcode, opening_hours]
# Index: []

# %% [markdown]
# ## Get data types of all variables

# %%
# Get data types (note that in pandas, a string is referred to as 'object')
df.dtypes
# Out:
# type                 object
# id                    int64
# lat                 float64
# lon                 float64
# brand                object
# shop                 object
# addr:city            object
# addr:housenumber     object
# addr:postcode        object
# opening_hours        object
# dtype: object

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('supermarkets_data_prepared.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 21.6.0
# Datetime: 2022-09-30 15:07:40
# Python Version: 3.9.13
# -----------------------------------

# %% [markdown]
# # My Task

# %% [markdown]
# ### Filter only Migros supermarkets in the city of Zürich.

# %%
df_filtered = df.loc[(df['brand'] == 'Migros') & (df['addr:city'] == 'Zürich')]
df_filtered.head(5)
# Out:
#     type         id        lat       lon   brand         shop addr:city  \
# 4   node   48932835  47.375020  8.522895  Migros  supermarket    Zürich
# 11  node   83330862  47.344749  8.529981  Migros  supermarket    Zürich
# 16  node  119249170  47.375255  8.536107  Migros  supermarket    Zürich
# 50  node  262400822  47.364072  8.530945  Migros  supermarket    Zürich
# 71  node  267346993  47.385598  8.531471  Migros  supermarket    Zürich
#
#    addr:housenumber addr:postcode                            opening_hours
# 4                 7          8004                Mo-Sa 08:00-21:00; PH off
# 11                3          8038                Mo-Sa 07:30-21:00; PH off
# 16            31-35          8001                Mo-Sa 09:00-20:00; PH off
# 50               10          8002  Mo-Fr 06:30-22:00; PH,Sa-Su 08:00-22:00
# 71              152          8005                Mo-Sa 07:30-20:00; PH off

# %% [markdown]
# ### Filter and count all Coop supermarkets in the cities of Zürich, Basel & Bern.

# %%
df_filtered = df.loc[(df['brand'] == 'Coop') & ((df['addr:city'] == 'Zürich') | (df['addr:city'] == 'Bern') | (df['addr:city'] == 'Basel'))]
display(df_filtered)

print('Amount of Coop supermarkets in Basel, Bern & Zurich:', df_filtered.shape[0])
# Out:
#       type          id        lat       lon brand         shop addr:city  \
# 3     node    39947904  47.376732  8.542161  Coop  supermarket    Zürich
# 9     node    79977755  47.340070  8.530546  Coop  supermarket    Zürich
# 59    node   265776668  47.376417  8.559594  Coop  supermarket    Zürich
# 75    node   268603429  47.367360  8.546174  Coop  supermarket    Zürich
# 81    node   270692983  47.357940  8.554646  Coop  supermarket    Zürich
# 84    node   271028686  47.366770  8.548146  Coop  supermarket    Zürich
# 96    node   276363821  47.418888  8.505699  Coop  supermarket    Zürich
# 122   node   283103824  47.393648  8.529543  Coop  supermarket    Zürich
# 123   node   283126967  47.392524  8.524519  Coop  supermarket    Zürich
# 226   node   321361788  47.395725  8.540471  Coop  supermarket    Zürich
# 447   node   470217716  47.384789  8.527125  Coop  supermarket    Zürich
# 497   node   514589840  46.959297  7.455153  Coop  supermarket      Bern
# 625   node   651273252  47.373288  8.530562  Coop  supermarket    Zürich
# 632   node   659862626  47.375896  8.487025  Coop  supermarket    Zürich
# 692   node   707688653  47.569095  7.579643  Coop  supermarket     Basel
# 725   node   766705800  47.413421  8.540576  Coop  supermarket    Zürich
# 901   node  1027136881  47.425628  8.496976  Coop  supermarket    Zürich
# 1022  node  1322305936  47.545220  7.588710  Coop  supermarket     Basel
# 1118  node  1513116290  47.569082  7.590574  Coop  supermarket     Basel
# 1147  node  1598176926  47.543122  7.593269  Coop  supermarket     Basel
# 1150  node  1598954903  47.555210  7.613846  Coop  supermarket     Basel
# 1244  node  1756956245  47.370252  8.537156  Coop  supermarket    Zürich
# 1459  node  2264702137  47.387410  8.488921  Coop  supermarket    Zürich
# 1484  node  2323174782  47.377731  8.534719  Coop  supermarket    Zürich
# 1624  node  2663868342  47.570592  7.573368  Coop  supermarket     Basel
# 1727  node  2984223833  47.386262  8.499678  Coop  supermarket    Zürich
# 1837  node  3339748067  46.943501  7.406031  Coop  supermarket      Bern
# 2036  node  4039021088  46.948998  7.437534  Coop  supermarket      Bern
# 2043  node  4069816589  46.945398  7.426830  Coop  supermarket      Bern
# 2123  node  4328291097  47.347186  8.533072  Coop  supermarket    Zürich
# 2134  node  4342407034  47.565114  7.617822  Coop  supermarket     Basel
# 2179  node  4424679510  47.377825  8.538369  Coop  supermarket    Zürich
# 2195  node  4466482789  47.380692  8.534890  Coop  supermarket    Zürich
# 2308  node  4845976788  47.357415  8.523105  Coop  supermarket    Zürich
# 2309  node  4848816876  47.372928  8.537713  Coop  supermarket    Zürich
# 2324  node  4896104281  47.357451  8.523126  Coop  supermarket    Zürich
# 2326  node  4896104283  47.410477  8.546741  Coop  supermarket    Zürich
# 2575  node  6011935004  47.412872  8.547012  Coop  supermarket    Zürich
# 2947  node  8098492384  47.561065  7.591392  Coop  supermarket     Basel
# 2948  node  8098492385  47.576962  7.591138  Coop  supermarket     Basel
#
#      addr:housenumber addr:postcode  \
# 3                   1          8001
# 9                  15          8038
# 59                 75          8044
# 75                 18          8001
# 81                123          8008
# 84                 10          8001
# 96                549          8046
# 122                12          8037
# 123                22          8037
# 226               1-5          8057
# 447                48          8005
# 497                 2          3014
# 625                15          8004
# 632               334          8047
# 692                36          4056
# 725                 4          8050
# 901               199          8046
# 1022              125          4053
# 1118              142          4057
# 1147              190          4053
# 1150               37          4052
# 1244               16          8001
# 1459              650          8048
# 1484                5          8004
# 1624               10          4056
# 1727               50          8048
# 1837                1          3008
# 2036               10          3011
# 2043               20          3007
# 2123              339          8038
# 2134          132/134          4058
# 2179              NaN          8001
# 2195               42          8005
# 2308                1          8045
# 2309               57          8001
# 2324                1          8045
# 2326                1          8050
# 2575                5          8050
# 2947                3          4058
# 2948               76          4057
#
#                                           opening_hours
# 3                                     Mo-Sa 06:00-22:00
# 9                                     Mo-Sa 07:30-21:00
# 59                    Mo-Fr 07:30-21:00; Sa 07:30-20:00
# 75                    Mo-Fr 08:00-20:00; Sa 08:00-19:00
# 81                                    Mo-Sa 07:00-22:00
# 84                    Mo-Sa 06:00-22:00; Su 07:00-22:00
# 96                                    Mo-Sa 08:00-20:00
# 122                                   Mo-Sa 07:00-21:00
# 123                                   Mo-Sa 07:30-20:00
# 226                                   Mo-Sa 07:30-21:00
# 447                                   Mo-Sa 07:00-21:00
# 497                   Mo-Fr 07:30-20:00, Sa 07:30-17:00
# 625                                   Mo-Sa 07:00-21:00
# 632                                   Mo-Sa 08:00-20:00
# 692                   Mo-Fr 07:30-20:00; Sa 07:30-18:00
# 725                                   Mo-Sa 07:30-21:00
# 901                                   Mo-Sa 08:00-20:00
# 1022                                  Mo-Sa 07:00-22:00
# 1118                  Mo-Fr 07:30-20:00; Sa 07:30-18:00
# 1147                                                NaN
# 1150                  Mo-Fr 07:30-20:00; Sa 07:30-18:00
# 1244                  Mo-Fr 07:00-20:00; Sa 07:00-17:00
# 1459                                  Mo-Sa 07:30-20:00
# 1484                  Mo-Fr 06:30-22:00; Sa 08:00-20:00
# 1624                  Mo-Fr 07:30-20:00; Sa 07:30-18:00
# 1727                                  Mo-Sa 09:00-20:00
# 1837                  Mo-Fr 07:00-20:00; Sa 08:00-17:00
# 2036  Mo-We, Fr 06:00-20:00; Th 06:00-21:00; Sa 07:0...
# 2043          Mo-Fr 07:00-20:00; Sa 07:00-17:00; Su off
# 2123                  Mo-Fr 07:00-21:00; Sa 08:00-21:00
# 2134                  Mo-Fr 07:30-20:00, Sa 07:30-18:00
# 2179                  Mo-Sa 06:00-22:00; Su 08:00-22:00
# 2195                                  Mo-Sa 07:00-21:00
# 2308                                  Mo-Sa 09:00-20:00
# 2309                                  Mo-Sa 09:00-20:00
# 2324                  Mo-Fr 09:00-21:00; Sa 08:00-21:00
# 2326                  Mo-Fr 08:00-20:00; Sa 08:00-18:00
# 2575                  Mo-Fr 06:30-20:00; Sa 08:00-20:00
# 2947                  Mo-Fr 06:30-20:00; Sa 07:30-18:00
# 2948                  Mo-Fr 07:30-20:00; Sa 07:30-18:00
# Amount of Coop supermarkets in Basel, Bern & Zurich: 40

# %% [markdown]
# ### Filter supermarkets with available opening hours.

# %%
df_filtered['opening_hours'].dropna()
df_filtered.head(5)
# Out:
#     type         id        lat       lon brand         shop addr:city  \
# 3   node   39947904  47.376732  8.542161  Coop  supermarket    Zürich
# 9   node   79977755  47.340070  8.530546  Coop  supermarket    Zürich
# 59  node  265776668  47.376417  8.559594  Coop  supermarket    Zürich
# 75  node  268603429  47.367360  8.546174  Coop  supermarket    Zürich
# 81  node  270692983  47.357940  8.554646  Coop  supermarket    Zürich
#
#    addr:housenumber addr:postcode                      opening_hours
# 3                 1          8001                  Mo-Sa 06:00-22:00
# 9                15          8038                  Mo-Sa 07:30-21:00
# 59               75          8044  Mo-Fr 07:30-21:00; Sa 07:30-20:00
# 75               18          8001  Mo-Fr 08:00-20:00; Sa 08:00-19:00
# 81              123          8008                  Mo-Sa 07:00-22:00

# %% [markdown]
# ### Filter supermarkets with available brand, city, house number and postcode.

# %%
df_filtered = df[['brand', 'addr:city','addr:housenumber','addr:postcode']].dropna()
df_filtered
# Out:
#        brand        addr:city addr:housenumber addr:postcode
# 1     Migros           Uznach               25          8730
# 3       Coop           Zürich                1          8001
# 4     Migros           Zürich                7          8004
# 7     Migros       Winterthur              102          8406
# 8       ALDI           Zürich               81          8038
# ...      ...              ...              ...           ...
# 3211    Coop        Brienz BE             139b          3855
# 3222  Denner           Gampel                5          3945
# 3248  Denner        Echallens                2          1040
# 3254    Volg       Marbach SG               17          9437
# 3256   Landi  Rickenbach Sulz                1          8545
#
# [928 rows x 4 columns]
